# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
s_a=np.array([75,65,73,68,72,76])
s_b=np.array([90,47,43,96,93,51])

# %%
np.std(s_a),np.std(s_b)
# Out:
# (np.float64(3.8622100754188224), np.float64(23.18045153428495))

# %%
np.var(s_a),np.var(s_b)
# Out:
# (np.float64(14.916666666666666), np.float64(537.3333333333334))

# %%
data=pd.read_csv("/home/jobayer/Git/titanic/train.csv")

# %%
np.std(data["Age"])
# Out:
# np.float64(14.516321150817316)

# %%
sns.histplot(x="Age",data=data)
plt.show()
